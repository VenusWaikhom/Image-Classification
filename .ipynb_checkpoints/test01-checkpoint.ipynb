# %% [markdown]
# ### **Import** **Libraries**
#
#
# ---

# %%
import os
import random
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, GlobalAveragePooling2D, Dropout, InputLayer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import model_to_dot
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from sklearn.model_selection import KFold
from keras.utils import plot_model
from IPython.display import Image
# Out:
# C:\Users\Jardani\anaconda3\envs\tf\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import pydot
from sklearn import __version__ as sklearn_version
from keras import __version__ as keras_version
from IPython import __version__ as ipython_version


print("pydot version: {pydot.__version__}")
print("matplotlib version: {plt.__version__}")
print("OpenCV version:", cv2.__version__)
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
print("TensorFlow version:", tf.__version__)
print("Seaborn version:", sns.__version__)
print("Scikit-learn version:", sklearn_version)
print("Keras version:", keras_version)
print("IPython version:", ipython_version)
# Out:
# pydot version: {pydot.__version__}
# matplotlib version: {plt.__version__}
# OpenCV version: 4.9.0
# Pandas version: 2.2.2
# NumPy version: 1.26.4
# TensorFlow version: 2.10.1
# Seaborn version: 0.13.2
# Scikit-learn version: 1.5.0
# Keras version: 2.10.0
# IPython version: 8.15.0

# %% [markdown]
# ### **Image Path Declearation and dividing test and Traning 9:1**
#
# ---

# %%
image_directory = r'C:\Users\Jardani\Desktop\Venus Folder\256_Size_Object_Classification_Images'

# %%
class_labels = sorted(os.listdir(image_directory))

with open('class_labels.txt', 'w') as file:
    for label in class_labels:
        file.write(label + '\n')

print("Class Labels:", class_labels)
# Out:
# Class Labels: ['Bike', 'Car', 'Cat', 'Chair', 'Cup', 'Dog', 'Person', 'Sofa']

# %%
def get_image_paths_and_labels(image_directory):
    classes = [d for d in os.listdir(image_directory) if os.path.isdir(os.path.join(image_directory, d))]
    file_paths = []
    labels = []

    for class_name in classes:
        class_dir = os.path.join(image_directory, class_name)
        images = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))]
        file_paths.extend([os.path.join(class_dir, image) for image in images])
        labels.extend([class_name] * len(images))

    return file_paths, labels

# %%
def shuffle_and_split_data(file_paths, labels, test_ratio=0.1):
    data = list(zip(file_paths, labels))
    random.shuffle(data)
    file_paths, labels = zip(*data)

    split_index = int(len(file_paths) * (1 - test_ratio))
    train_paths, test_paths = file_paths[:split_index], file_paths[split_index:]
    train_labels, test_labels = labels[:split_index], labels[split_index:]

    return train_paths, train_labels, test_paths, test_labels

# %%
file_paths, labels = get_image_paths_and_labels(image_directory)

# %%
train_paths, train_labels, test_paths, test_labels = shuffle_and_split_data(file_paths, labels, test_ratio=0.1)

# %%
train_val_df = pd.DataFrame({'filename': train_paths, 'class': train_labels})
test_df = pd.DataFrame({'filename': test_paths, 'class': test_labels})

# %% [markdown]
# ### **Declearing Image Size And Epochs**
#
# ---

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 256, 256
BATCH_SIZE = 32
EPOCHS = 100
K = 5

NUM_CLASSES = len(class_labels)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ### **K-Fold > Traning**
#
# ---

# %%
kf = KFold(n_splits=5, shuffle=True)
fold_no = 1
all_train_histories = []

for train_index, val_index in kf.split(train_val_df):
    print(f'Fold {fold_no}')

    train_df = train_val_df.iloc[train_index]
    validation_df = train_val_df.iloc[val_index]

    train_generator = train_datagen.flow_from_dataframe(
        train_df,
        x_col='filename',
        y_col='class',
        target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
        batch_size=BATCH_SIZE,
        class_mode='categorical'
    )

    validation_generator = validation_datagen.flow_from_dataframe(
        validation_df,
        x_col='filename',
        y_col='class',
        target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
        batch_size=BATCH_SIZE,
        class_mode='categorical'
    )

    model = Sequential([
      InputLayer(input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT,3)),
      Conv2D(16, (3, 3), activation='relu'),
      Conv2D(16, (3, 3), activation='relu'),
      MaxPooling2D((2, 2), strides=2),
      Conv2D(32, (3, 3), activation='relu'),
      Conv2D(32, (3, 3), activation='relu'),
      MaxPooling2D((2, 2), strides=2),
      Conv2D(64, (3, 3), activation='relu'),
      Conv2D(64, (3, 3), activation='relu'),
      Conv2D(64, (3, 3), activation='relu'),
      MaxPooling2D((2, 2), strides=2),
      Conv2D(128, (3, 3), activation='relu'),
      Conv2D(128, (3, 3), activation='relu'),
      Conv2D(128, (3, 3), activation='relu'),
      GlobalAveragePooling2D(),
      Dense(128, activation='relu'),
      Dropout(0.2),
      Dense(NUM_CLASSES, activation='softmax')
  ])

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

    checkpoint_path = f'model_fold_{fold_no}.h5'
    checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )

    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=5,
        restore_best_weights=True
    )

    history = model.fit(
        train_generator,
        epochs=EPOCHS,
        validation_data=validation_generator,
        callbacks=[checkpoint, early_stopping]
    )

    all_train_histories.append(history.history)

    best_model = load_model(checkpoint_path)

    scores = best_model.evaluate(validation_generator)
    print(f'Score for fold {fold_no}: {best_model.metrics_names[0]} of {scores[0]}; {best_model.metrics_names[1]} of {scores[1]*100}%')

    fold_no += 1
# Out:
# Fold 1
# Found 10828 validated image filenames belonging to 8 classes.
# Found 2708 validated image filenames belonging to 8 classes.
# Epoch 1/100
# 339/339 [==============================] - ETA: 0s - loss: 1.9077 - accuracy: 0.2206
# Epoch 1: val_accuracy improved from -inf to 0.38885, saving model to model_fold_1.h5
# 339/339 [==============================] - 81s 229ms/step - loss: 1.9077 - accuracy: 0.2206 - val_loss: 1.6105 - val_accuracy: 0.3888
# Epoch 2/100
# 339/339 [==============================] - ETA: 0s - loss: 1.5693 - accuracy: 0.3838
# Epoch 2: val_accuracy improved from 0.38885 to 0.47526, saving model to model_fold_1.h5
# 339/339 [==============================] - 75s 220ms/step - loss: 1.5693 - accuracy: 0.3838 - val_loss: 1.4104 - val_accuracy: 0.4753
# Epoch 3/100
# 339/339 [==============================] - ETA: 0s - loss: 1.3248 - accuracy: 0.4874
# Epoch 3: val_accuracy improved from 0.47526 to 0.53693, saving model to model_fold_1.h5
# 339/339 [==============================] - 75s
saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 1.2936 - accuracy: 0.5053 - val_loss: 1.2224 - val_accuracy: 0.5338
# Epoch 4/100
# 339/339 [==============================] - ETA: 0s - loss: 1.1456 - accuracy: 0.5677
# Epoch 4: val_accuracy improved from 0.53380 to 0.61286, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 214ms/step - loss: 1.1456 - accuracy: 0.5677 - val_loss: 1.0484 - val_accuracy: 0.6129
# Epoch 5/100
# 339/339 [==============================] - ETA: 0s - loss: 1.0128 - accuracy: 0.6190
# Epoch 5: val_accuracy did not improve from 0.61286
# 339/339 [==============================] - 73s 214ms/step - loss: 1.0128 - accuracy: 0.6190 - val_loss: 1.0047 - val_accuracy: 0.6106
# Epoch 6/100
# 339/339 [==============================] - ETA: 0s - loss: 0.9434 - accuracy: 0.6425
# Epoch 6: val_accuracy improved from 0.61286 to 0.65017, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 214ms/step - loss: 0.9434 - accuracy: 0.6425 - val_loss: 0.9153 - val_accuracy: 0.6502
# Epoch 7/100
# 339/339 [==============================] - ETA: 0s - loss: 0.8667 - accuracy: 0.6731
# Epoch 7: val_accuracy improved from 0.65017 to 0.67566, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.8667 - accuracy: 0.6731 - val_loss: 0.8537 - val_accuracy: 0.6757
# Epoch 8/100
# 339/339 [==============================] - ETA: 0s - loss: 0.8430 - accuracy: 0.6820
# Epoch 8: val_accuracy improved from 0.67566 to 0.68341, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.8430 - accuracy: 0.6820 - val_loss: 0.8661 - val_accuracy: 0.6834
# Epoch 9/100
# 339/339 [==============================] - ETA: 0s - loss: 0.7840 - accuracy: 0.7054
# Epoch 9: val_accuracy did not improve from 0.68341
# 339/339 [==============================] - 73s 215ms/step - loss: 0.7840 - accuracy: 0.7054 - val_loss: 0.9288 - val_accuracy: 0.6291
# Epoch 10/100
# 339/339 [==============================] - ETA: 0s - loss: 0.7445 - accuracy: 0.7205
# Epoch 10: val_accuracy improved from 0.68341 to 0.74030, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.7445 - accuracy: 0.7205 - val_loss: 0.7000 - val_accuracy: 0.7403
# Epoch 11/100
# 339/339 [==============================] - ETA: 0s - loss: 0.7025 - accuracy: 0.7340
# Epoch 11: val_accuracy improved from 0.74030 to 0.75803, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.7025 - accuracy: 0.7340 - val_loss: 0.6547 - val_accuracy: 0.7580
# Epoch 12/100
# 339/339 [==============================] - ETA: 0s - loss: 0.6705 - accuracy: 0.7524
# Epoch 12: val_accuracy improved from 0.75803 to 0.76801, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.6705 - accuracy: 0.7524 - val_loss: 0.6258 - val_accuracy: 0.7680
# Epoch 13/100
# 339/339 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.7566
# Epoch 13: val_accuracy did not improve from 0.76801
# 339/339 [==============================] - 73s 216ms/step - loss: 0.6476 - accuracy: 0.7566 - val_loss: 0.6878 - val_accuracy: 0.7481
# Epoch 14/100
# 339/339 [==============================] - ETA: 0s - loss: 0.6179 - accuracy: 0.7696
# Epoch 14: val_accuracy improved from 0.76801 to 0.77503, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 214ms/step - loss: 0.6179 - accuracy: 0.7696 - val_loss: 0.6070 - val_accuracy: 0.7750
# Epoch 15/100
# 339/339 [==============================] - ETA: 0s - loss: 0.5944 - accuracy: 0.7841
# Epoch 15: val_accuracy improved from 0.77503 to 0.79017, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.5944 - accuracy: 0.7841 - val_loss: 0.5900 - val_accuracy: 0.7902
# Epoch 16/100
# 339/339 [==============================] - ETA: 0s - loss: 0.5463 - accuracy: 0.8022
# Epoch 16: val_accuracy did not improve from 0.79017
# 339/339 [==============================] - 73s 215ms/step - loss: 0.5463 - accuracy: 0.8022 - val_loss: 0.6376 - val_accuracy: 0.7617
# Epoch 17/100
# 339/339 [==============================] - ETA: 0s - loss: 0.5169 - accuracy: 0.8153
# Epoch 17: val_accuracy improved from 0.79017 to 0.81714, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.5169 - accuracy: 0.8153 - val_loss: 0.5244 - val_accuracy: 0.8171
# Epoch 18/100
# 339/339 [==============================] - ETA: 0s - loss: 0.4865 - accuracy: 0.8205
# Epoch 18: val_accuracy improved from 0.81714 to 0.83339, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.4865 - accuracy: 0.8205 - val_loss: 0.4699 - val_accuracy: 0.8334
# Epoch 19/100
# 339/339 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.8301
# Epoch 19: val_accuracy did not improve from 0.83339
# 339/339 [==============================] - 73s 216ms/step - loss: 0.4779 - accuracy: 0.8301 - val_loss: 0.5688 - val_accuracy: 0.8035
# Epoch 20/100
# 339/339 [==============================] - ETA: 0s - loss: 0.4545 - accuracy: 0.8365
# Epoch 20: val_accuracy did not improve from 0.83339
# 339/339 [==============================] - 73s 215ms/step - loss: 0.4545 - accuracy: 0.8365 - val_loss: 0.4881 - val_accuracy: 0.8182
# Epoch 21/100
# 339/339 [==============================] - ETA: 0s - loss: 0.4231 - accuracy: 0.8531
# Epoch 21: val_accuracy improved from 0.83339 to 0.84595, saving model to model_fold_4.h5
# 339/339 [==============================] - 74s 218ms/step - loss: 0.4231 - accuracy: 0.8531 - val_loss: 0.4428 - val_accuracy: 0.8460
# Epoch 22/100
# 339/339 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.8546
# Epoch 22: val_accuracy improved from 0.84595 to 0.85704, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.4090 - accuracy: 0.8546 - val_loss: 0.4162 - val_accuracy: 0.8570
# Epoch 23/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3848 - accuracy: 0.8672
# Epoch 23: val_accuracy improved from 0.85704 to 0.87588, saving model to model_fold_4.h5
# 339/339 [==============================] - 74s 217ms/step - loss: 0.3848 - accuracy: 0.8672 - val_loss: 0.3827 - val_accuracy: 0.8759
# Epoch 24/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.8690
# Epoch 24: val_accuracy did not improve from 0.87588
# 339/339 [==============================] - 73s 216ms/step - loss: 0.3726 - accuracy: 0.8690 - val_loss: 0.5303 - val_accuracy: 0.8175
# Epoch 25/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8728
# Epoch 25: val_accuracy improved from 0.87588 to 0.88733, saving model to model_fold_4.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.3649 - accuracy: 0.8728 - val_loss: 0.3432 - val_accuracy: 0.8873
# Epoch 26/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8826
# Epoch 26: val_accuracy did not improve from 0.88733
# 339/339 [==============================] - 73s 216ms/step - loss: 0.3328 - accuracy: 0.8826 - val_loss: 0.4211 - val_accuracy: 0.8559
# Epoch 27/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.8858
# Epoch 27: val_accuracy did not improve from 0.88733
# 339/339 [==============================] - 73s 214ms/step - loss: 0.3240 - accuracy: 0.8858 - val_loss: 0.4673 - val_accuracy: 0.8345
# Epoch 28/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3123 - accuracy: 0.8865
# Epoch 28: val_accuracy did not improve from 0.88733
# 339/339 [==============================] - 73s 215ms/step - loss: 0.3123 - accuracy: 0.8865 - val_loss: 0.3964 - val_accuracy: 0.8681
# Epoch 29/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3122 - accuracy: 0.8920
# Epoch 29: val_accuracy did not improve from 0.88733
# 339/339 [==============================] - 73s 215ms/step - loss: 0.3122 - accuracy: 0.8920 - val_loss: 0.4547 - val_accuracy: 0.8537
# Epoch 30/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.8973
# Epoch 30: val_accuracy did not improve from 0.88733
# 339/339 [==============================] - 73s 215ms/step - loss: 0.2930 - accuracy: 0.8973 - val_loss: 0.3411 - val_accuracy: 0.8862
# 85/85 [==============================] - 2s 27ms/step - loss: 0.3432 - accuracy: 0.8873
# Score for fold 4: loss of 0.3431668281555176; accuracy of 88.73291611671448%
# Fold 5
# Found 10829 validated image filenames belonging to 8 classes.
# Found 2707 validated image filenames belonging to 8 classes.
# Epoch 1/100
# 339/339 [==============================] - ETA: 0s - loss: 1.9363 - accuracy: 0.2119
# Epoch 1: val_accuracy improved from -inf to 0.30403, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 214ms/step - loss: 1.9363 - accuracy: 0.2119 - val_loss: 1.7955 - val_accuracy: 0.3040
# Epoch 2/100
# 339/339 [==============================] - ETA: 0s - loss: 1.6262 - accuracy: 0.3901
# Epoch 2: val_accuracy improved from 0.30403 to 0.47580, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 214ms/step - loss: 1.6262 - accuracy: 0.3901 - val_loss: 1.4118 - val_accuracy: 0.4758
# Epoch 3/100
# 339/339 [==============================] - ETA: 0s - loss: 1.3736 - accuracy: 0.4837
# Epoch 3: val_accuracy improved from 0.47580 to 0.53158, saving model to model_fold_5.h5
# 339/339 [==============================] - 74s 217ms/step - loss: 1.3736 - accuracy: 0.4837 - val_loss: 1.2234 - val_accuracy: 0.5316
# Epoch 4/100
# 339/339 [==============================] - ETA: 0s - loss: 1.2213 - accuracy: 0.5364
# Epoch 4: val_accuracy improved from 0.53158 to 0.57739, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 214ms/step - loss: 1.2213 - accuracy: 0.5364 - val_loss: 1.0693 - val_accuracy: 0.5774
# Epoch 5/100
# 339/339 [==============================] - ETA: 0s - loss: 1.0819 - accuracy: 0.5893
# Epoch 5: val_accuracy improved from 0.57739 to 0.61286, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 1.0819 - accuracy: 0.5893 - val_loss: 1.0108 - val_accuracy: 0.6129
# Epoch 6/100
# 339/339 [==============================] - ETA: 0s - loss: 0.9695 - accuracy: 0.6293
# Epoch 6: val_accuracy improved from 0.61286 to 0.66236, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.9695 - accuracy: 0.6293 - val_loss: 0.8880 - val_accuracy: 0.6624
# Epoch 7/100
# 339/339 [==============================] - ETA: 0s - loss: 0.9096 - accuracy: 0.6495
# Epoch 7: val_accuracy did not improve from 0.66236
# 339/339 [==============================] - 79s 234ms/step - loss: 0.9096 - accuracy: 0.6495 - val_loss: 0.8727 - val_accuracy: 0.6609
# Epoch 8/100
# 339/339 [==============================] - ETA: 0s - loss: 0.8620 - accuracy: 0.6668
# Epoch 8: val_accuracy improved from 0.66236 to 0.69560, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 214ms/step - loss: 0.8620 - accuracy: 0.6668 - val_loss: 0.7950 - val_accuracy: 0.6956
# Epoch 9/100
# 339/339 [==============================] - ETA: 0s - loss: 0.8257 - accuracy: 0.6798
# Epoch 9: val_accuracy did not improve from 0.69560
# 339/339 [==============================] - 73s 214ms/step - loss: 0.8257 - accuracy: 0.6798 - val_loss: 0.8590 - val_accuracy: 0.6745
# Epoch 10/100
# 339/339 [==============================] - ETA: 0s - loss: 0.7986 - accuracy: 0.6920
# Epoch 10: val_accuracy improved from 0.69560 to 0.72220, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 214ms/step - loss: 0.7986 - accuracy: 0.6920 - val_loss: 0.7322 - val_accuracy: 0.7222
# Epoch 11/100
# 339/339 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.7159
# Epoch 11: val_accuracy improved from 0.72220 to 0.72516, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.7444 - accuracy: 0.7159 - val_loss: 0.7250 - val_accuracy: 0.7252
# Epoch 12/100
# 339/339 [==============================] - ETA: 0s - loss: 0.7076 - accuracy: 0.7287
# Epoch 12: val_accuracy improved from 0.72516 to 0.74067, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.7076 - accuracy: 0.7287 - val_loss: 0.6709 - val_accuracy: 0.7407
# Epoch 13/100
# 339/339 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.7380
# Epoch 13: val_accuracy improved from 0.74067 to 0.76395, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.6921 - accuracy: 0.7380 - val_loss: 0.6302 - val_accuracy: 0.7639
# Epoch 14/100
# 339/339 [==============================] - ETA: 0s - loss: 0.6565 - accuracy: 0.7522
# Epoch 14: val_accuracy improved from 0.76395 to 0.77909, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.6565 - accuracy: 0.7522 - val_loss: 0.5936 - val_accuracy: 0.7791
# Epoch 15/100
# 339/339 [==============================] - ETA: 0s - loss: 0.6257 - accuracy: 0.7673
# Epoch 15: val_accuracy improved from 0.77909 to 0.78057, saving model to model_fold_5.h5
# 339/339 [==============================] - 74s 217ms/step - loss: 0.6257 - accuracy: 0.7673 - val_loss: 0.5923 - val_accuracy: 0.7806
# Epoch 16/100
# 339/339 [==============================] - ETA: 0s - loss: 0.6043 - accuracy: 0.7736
# Epoch 16: val_accuracy improved from 0.78057 to 0.79017, saving model to model_fold_5.h5
# 339/339 [==============================] - 74s 217ms/step - loss: 0.6043 - accuracy: 0.7736 - val_loss: 0.5629 - val_accuracy: 0.7902
# Epoch 17/100
# 339/339 [==============================] - ETA: 0s - loss: 0.5717 - accuracy: 0.7827
# Epoch 17: val_accuracy improved from 0.79017 to 0.79387, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.5717 - accuracy: 0.7827 - val_loss: 0.5818 - val_accuracy: 0.7939
# Epoch 18/100
# 339/339 [==============================] - ETA: 0s - loss: 0.5488 - accuracy: 0.7955
# Epoch 18: val_accuracy did not improve from 0.79387
# 339/339 [==============================] - 73s 215ms/step - loss: 0.5488 - accuracy: 0.7955 - val_loss: 0.5287 - val_accuracy: 0.7905
# Epoch 19/100
# 339/339 [==============================] - ETA: 0s - loss: 0.5412 - accuracy: 0.7996
# Epoch 19: val_accuracy did not improve from 0.79387
# 339/339 [==============================] - 74s 217ms/step - loss: 0.5412 - accuracy: 0.7996 - val_loss: 0.5439 - val_accuracy: 0.7935
# Epoch 20/100
# 339/339 [==============================] - ETA: 0s - loss: 0.5101 - accuracy: 0.8103
# Epoch 20: val_accuracy improved from 0.79387 to 0.81936, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.5101 - accuracy: 0.8103 - val_loss: 0.5039 - val_accuracy: 0.8194
# Epoch 21/100
# 339/339 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.8211
# Epoch 21: val_accuracy did not improve from 0.81936
# 339/339 [==============================] - 73s 216ms/step - loss: 0.4876 - accuracy: 0.8211 - val_loss: 0.5454 - val_accuracy: 0.8020
# Epoch 22/100
# 339/339 [==============================] - ETA: 0s - loss: 0.4688 - accuracy: 0.8303
# Epoch 22: val_accuracy did not improve from 0.81936
# 339/339 [==============================] - 73s 215ms/step - loss: 0.4688 - accuracy: 0.8303 - val_loss: 0.5096 - val_accuracy: 0.8105
# Epoch 23/100
# 339/339 [==============================] - ETA: 0s - loss: 0.4439 - accuracy: 0.8383
# Epoch 23: val_accuracy improved from 0.81936 to 0.84485, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.4439 - accuracy: 0.8383 - val_loss: 0.4375 - val_accuracy: 0.8448
# Epoch 24/100
# 339/339 [==============================] - ETA: 0s - loss: 0.4188 - accuracy: 0.8545
# Epoch 24: val_accuracy did not improve from 0.84485
# 339/339 [==============================] - 73s 215ms/step - loss: 0.4188 - accuracy: 0.8545 - val_loss: 0.4553 - val_accuracy: 0.8352
# Epoch 25/100
# 338/339 [============================>.] - ETA: 0s - loss: 0.4064 - accuracy: 0.8544
# Epoch 25: val_accuracy did not improve from 0.84485
# 339/339 [==============================] - 73s 216ms/step - loss: 0.4062 - accuracy: 0.8544 - val_loss: 0.4954 - val_accuracy: 0.8360
# Epoch 26/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3973 - accuracy: 0.8567
# Epoch 26: val_accuracy improved from 0.84485 to 0.85187, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.3973 - accuracy: 0.8567 - val_loss: 0.4377 - val_accuracy: 0.8519
# Epoch 27/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3831 - accuracy: 0.8648
# Epoch 27: val_accuracy did not improve from 0.85187
# 339/339 [==============================] - 73s 216ms/step - loss: 0.3831 - accuracy: 0.8648 - val_loss: 0.4525 - val_accuracy: 0.8467
# Epoch 28/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3589 - accuracy: 0.8719
# Epoch 28: val_accuracy did not improve from 0.85187
# 339/339 [==============================] - 73s 216ms/step - loss: 0.3589 - accuracy: 0.8719 - val_loss: 0.4612 - val_accuracy: 0.8482
# Epoch 29/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3461 - accuracy: 0.8759
# Epoch 29: val_accuracy improved from 0.85187 to 0.86147, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.3461 - accuracy: 0.8759 - val_loss: 0.4254 - val_accuracy: 0.8615
# Epoch 30/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3313 - accuracy: 0.8847
# Epoch 30: val_accuracy did not improve from 0.86147
# 339/339 [==============================] - 74s 217ms/step - loss: 0.3313 - accuracy: 0.8847 - val_loss: 0.4085 - val_accuracy: 0.8548
# Epoch 31/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3299 - accuracy: 0.8835
# Epoch 31: val_accuracy improved from 0.86147 to 0.87034, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 216ms/step - loss: 0.3299 - accuracy: 0.8835 - val_loss: 0.4026 - val_accuracy: 0.8703
# Epoch 32/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3319 - accuracy: 0.8848
# Epoch 32: val_accuracy did not improve from 0.87034
# 339/339 [==============================] - 73s 215ms/step - loss: 0.3319 - accuracy: 0.8848 - val_loss: 0.5531 - val_accuracy: 0.8116
# Epoch 33/100
# 339/339 [==============================] - ETA: 0s - loss: 0.3185 - accuracy: 0.8889
# Epoch 33: val_accuracy did not improve from 0.87034
# 339/339 [==============================] - 73s 216ms/step - loss: 0.3185 - accuracy: 0.8889 - val_loss: 0.3922 - val_accuracy: 0.8618
# Epoch 34/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 0.9009
# Epoch 34: val_accuracy improved from 0.87034 to 0.87440, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.2907 - accuracy: 0.9009 - val_loss: 0.3780 - val_accuracy: 0.8744
# Epoch 35/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.9029
# Epoch 35: val_accuracy did not improve from 0.87440
# 339/339 [==============================] - 73s 216ms/step - loss: 0.2885 - accuracy: 0.9029 - val_loss: 0.4116 - val_accuracy: 0.8611
# Epoch 36/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.9073
# Epoch 36: val_accuracy improved from 0.87440 to 0.88179, saving model to model_fold_5.h5
# 339/339 [==============================] - 73s 215ms/step - loss: 0.2717 - accuracy: 0.9073 - val_loss: 0.3481 - val_accuracy: 0.8818
# Epoch 37/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2652 - accuracy: 0.9063
# Epoch 37: val_accuracy did not improve from 0.88179
# 339/339 [==============================] - 73s 216ms/step - loss: 0.2652 - accuracy: 0.9063 - val_loss: 0.4358 - val_accuracy: 0.8604
# Epoch 38/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9098
# Epoch 38: val_accuracy did not improve from 0.88179
# 339/339 [==============================] - 73s 215ms/step - loss: 0.2597 - accuracy: 0.9098 - val_loss: 0.4703 - val_accuracy: 0.8596
# Epoch 39/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2640 - accuracy: 0.9094
# Epoch 39: val_accuracy did not improve from 0.88179
# 339/339 [==============================] - 73s 216ms/step - loss: 0.2640 - accuracy: 0.9094 - val_loss: 0.3808 - val_accuracy: 0.8714
# Epoch 40/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2380 - accuracy: 0.9189
# Epoch 40: val_accuracy did not improve from 0.88179
# 339/339 [==============================] - 74s 217ms/step - loss: 0.2380 - accuracy: 0.9189 - val_loss: 0.3678 - val_accuracy: 0.8788
# Epoch 41/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.9188
# Epoch 41: val_accuracy did not improve from 0.88179
# 339/339 [==============================] - 73s 216ms/step - loss: 0.2367 - accuracy: 0.9188 - val_loss: 0.3987 - val_accuracy: 0.8740
# 85/85 [==============================] - 3s 29ms/step - loss: 0.3481 - accuracy: 0.8818
# Score for fold 5: loss of 0.348145067691803; accuracy of 88.17879557609558%

# %%
model.summary()

model_summary_file = f'model_summary.txt'
with open(model_summary_file, 'w') as f:
    model.summary(print_fn=lambda x: f.write(x + '\n'))

dot_model = model_to_dot(model, show_shapes=True, show_layer_names=True)

dot_model.write_png(f"model_summary.png")

Image(f"model_summary.png")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 254, 254, 16)      448
#
#  conv2d_41 (Conv2D)          (None, 252, 252, 16)      2320
#
#  max_pooling2d_12 (MaxPoolin  (None, 126, 126, 16)     0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 124, 124, 32)      4640
#
#  conv2d_43 (Conv2D)          (None, 122, 122, 32)      9248
#
#  max_pooling2d_13 (MaxPoolin  (None, 61, 61, 32)       0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 59, 59, 64)        18496
#
#  conv2d_45 (Conv2D)          (None, 57, 57, 64)        36928
#
#  conv2d_46 (Conv2D)          (None, 55, 55, 64)        36928
#
#  max_pooling2d_14 (MaxPoolin  (None, 27, 27, 64)       0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 25, 25, 128)       73856
#
#  conv2d_48 (Conv2D)          (None, 23, 23, 128)       147584
#
#  conv2d_49 (Conv2D)          (None, 21, 21, 128)       147584
#
#  global_average_pooling2d_4   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 495,576
# Trainable params: 495,576
# Non-trainable params: 0
# _________________________________________________________________

# %%
def plot_history(history, fold_no):
    plt.figure(figsize=(12, 4))
    
    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title(f'Model accuracy for fold {fold_no}')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.savefig(f'accuracy_fold_{fold_no}.png')
    
    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title(f'Model loss for fold {fold_no}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.savefig(f'loss_fold_{fold_no}.png')
    
    plt.show()
    plt.close()

# %%
for i, history in enumerate(all_train_histories):
    plot_history(history, i+1)

# %%
best_val_accuracy = 0.0
best_model_path = None
total_val_accuracy = 0.0

for Fold_No in range(K):
    checkpoint_path = f'model_fold_{Fold_No+1}.h5'
    model = load_model(checkpoint_path)

    validation_generator = validation_datagen.flow_from_dataframe(
        validation_df,
        x_col='filename',
        y_col='class',
        target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )

    scores = model.evaluate(validation_generator)
    val_accuracy = scores[1]
    total_val_accuracy += val_accuracy

    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        best_model_path = checkpoint_path

print(f'Best validation accuracy: {best_val_accuracy}')
average_val_accuracy = total_val_accuracy / K
print(f'Average validation accuracy: {average_val_accuracy}')

best_model.save("Best_Model.h5")

best_model = load_model("Best_Model.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 9
#       7 for Fold_No in range(K):
#       8     checkpoint_path = f'model_fold_{Fold_No}.h5'
# ----> 9     model = load_model(checkpoint_path)
#      11     validation_generator = validation_datagen.flow_from_dataframe(
#      12         validation_df,
#      13         x_col='filename',
#    (...)
#      18         shuffle=False
#      19     )
#      21     scores = model.evaluate(validation_generator)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\saving\save.py:226, in load_model(filepath, custom_objects, compile, options)
#     224 if isinstance(filepath_str, str):
#     225     if not tf.io.gfile.exists(filepath_str):
# --> 226         raise IOError(
#     227             f"No file or directory found at {filepath_str}"
#     228         )
#     230     if tf.io.gfile.isdir(filepath_str):
#     231         return saved_model_load.load(
#     232             filepath_str, compile, options
#     233         )
#
# OSError: No file or directory found at model_fold_0.h5

# %%
test_generator = validation_datagen.flow_from_dataframe(
    test_df,
    x_col='filename',
    y_col='class',
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# %%
test_scores = best_model.evaluate(test_generator)
print(f'Test set score: {best_model.metrics_names[0]} of {test_scores[0]}; {best_model.metrics_names[1]} of {test_scores[1]*100}%')

# %% [markdown]
# ### **CONFUSION MATRIX
#
# ---

# %%
Y_pred = best_model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_true = test_generator.classes

# %%
cm = confusion_matrix(y_true, y_pred)
cm_df = pd.DataFrame(cm, index=test_generator.class_indices.keys(), columns=test_generator.class_indices.keys())

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.savefig('confusion_matrix.png')

# %%
report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
with open('classification_report.txt', 'w') as f:
    f.write(report)

# %%
print(report)

# %% [markdown]
# ### **TESTING**
#
# ---

# %%
def load_and_preprocess_image(image_path):
    image = tf.keras.preprocessing.image.load_img(image_path, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
    image = tf.keras.preprocessing.image.img_to_array(image)
    image = image / 255.0
    return np.expand_dims(image, axis=0)

random_indices = random.sample(range(len(test_df)), 10)
random_images = test_df.iloc[random_indices]

results = pd.DataFrame(columns=['Image', 'Actual Class', 'Predicted Class', 'Prediction Score'])

for idx, row in random_images.iterrows():
    image_path = row['filename']
    actual_class = row['class']

    image = load_and_preprocess_image(image_path)
    prediction = best_model.predict(image)
    predicted_class_index = np.argmax(prediction, axis=1)[0]
    predicted_class_name = class_labels[predicted_class_index]
    prediction_score = prediction[0][predicted_class_index]

    new_row = pd.DataFrame({
        'Image': [image_path],
        'Actual Class': [actual_class],
        'Predicted Class': [predicted_class_name],
        'Prediction Score': [prediction_score]
    })
    results = pd.concat([results, new_row], ignore_index=True)

    plt.imshow(tf.keras.preprocessing.image.array_to_img(image[0]))
    plt.title(f"Actual: {actual_class}, Predicted: {predicted_class_name} (Score: {prediction_score:.4f})")
    plt.axis('off')
    plt.show()

print(results)
